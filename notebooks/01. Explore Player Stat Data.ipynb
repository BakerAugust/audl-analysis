# %% [markdown]
# # Objective
# - Explore player level stats by year for AUDL.
#     - Is it comprehensive?
#     - Are the reasons to suspect any gaps / bad data?
#     - What stats are available?
#
# # Summary
# - Data is aggregat
#
# # Next Steps

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
! ls -a ../../ultianalyticspull/ultianalyticspull/data/final/audl/
# Out:
# .                      all_goals.csv          team_stats.csv
# ..                     player_stats.csv       team_stats_by_year.csv

# %%
raw = pd.read_csv('../../ultianalyticspull/ultianalyticspull/data/final/audl/player_stats.csv')

# %%
raw.columns
# Out:
# Index(['year', 'team', 'player', 'Assists', 'Hockey Assists', 'Throws',
#        'Throwaways', 'Turnovers', 'Completions', 'Catches', 'Goals', 'Drops',
#        'Blocks', 'Stalls', 'Callahans', 'Callahans Thrown', 'Plus/Minus',
#        'Net Stats', 'O Points Played', 'O Possessions Played',
#        'D Points Played', 'D Possessions Played', 'Holds', 'Breaks',
#        'Games Played', 'O Opponent Possessions Played',
#        'D Opponent Possessions Played', 'O Points Lost', 'D Points Lost',
#        'Points Won', 'Points Played', 'Possessions Played', 'Completion Rate',
#        'Throwaway Rate', 'Assist Rate', 'Goal Rate', 'Hold Rate', 'Break Rate',
#        'Scoring Efficiency', 'O Scoring Efficiency', 'D Scoring Efficiency',
#        'O Takeaway Efficiency', 'D Takeaway Efficiency'],
#       dtype='object')

# %%
raw.head()
# Out:
#    year              team              player  Assists  Hockey Assists  \
# 0  2014  Chicago Wildfire           AJ Nelson     23.0            20.0
# 1  2014  Chicago Wildfire  Alex Drlica-Wagner      3.0             1.0
# 2  2014  Chicago Wildfire      Andrew Sheehan     15.0            14.0
# 3  2014  Chicago Wildfire        Andy Nielsen      2.0             1.0
# 4  2014  Chicago Wildfire           Anonymous     10.0             3.0
#
#    Throws  Throwaways  Turnovers  Completions  Catches  ...  Throwaway Rate  \
# 0   265.0        15.0       19.0        243.0    309.0  ...        0.056604
# 1    55.0         4.0        4.0         51.0     59.0  ...        0.072727
# 2   195.0        10.0       12.0        179.0    140.0  ...        0.051282
# 3    51.0         3.0        4.0         46.0     47.0  ...        0.058824
# 4    30.0        14.0       17.0         16.0     11.0  ...        0.466667
#
#    Assist Rate  Goal Rate  Hold Rate  Break Rate  Scoring Efficiency  \
# ...

# %%
pd.options.display.max_columns=50

# %%
raw[raw['Games Played']<5]
# Out:
#       year                     team                 player  Assists  \
# 8     2014         Chicago Wildfire           Brodie Smith      4.0
# 16    2014         Chicago Wildfire  George Hughes-Strange      4.0
# 25    2014         Chicago Wildfire                  Rob S      3.0
# 29    2014         Chicago Wildfire             Tim Fergus      0.0
# 41    2014    Cincinnati Revolution           Connor Haley      1.0
# ...    ...                      ...                    ...      ...
# 4677  2019  Pittsburgh Thunderbirds          Marquis Cofer      NaN
# 4678  2019  Pittsburgh Thunderbirds              Steve May      NaN
# 4684  2019        Tampa Bay Cannons       Austin Koffarnus      NaN
# 4685  2019        Tampa Bay Cannons                Barrett      NaN
# 4686  2019        Tampa Bay Cannons              Tron Bass      NaN
#
#       Hockey Assists  Throws  Throwaways  Turnovers  Completions  Catches  \
# 8                1.0    28.0         0.0        0.0         27.0     21.0
# ...

# %%
raw.shape
# Out:
# (4689, 43)
